# %% [markdown]
# # 텐서플로우 (Tensorflow)
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/TensorFlowLogo.svg/1200px-TensorFlowLogo.svg.png" width="300">
#
# - 가장 널리 쓰이는 딥러닝 프레임워크 중 하나
#
# - 구글이 주도적으로 개발하는 플랫폼
#
# - 파이썬, C++ API를 기본적으로 제공하고,
#   자바스크립트(JavaScript), 자바(Java), 고(Go), 스위프트(Swift) 등 다양한 프로그래밍 언어를 지원
#
# - tf.keras를 중심으로 고수준 API 통합 (2.x 버전)
#
# - TPU(Tensor Processing Unit) 지원
#   - TPU는 GPU보다 전력을 적게 소모, 경제적
#
#   - 일반적으로 32비트(float32)로 수행되는 곱셈 연산을 16비트(float16)로 낮춤

# %% [markdown]
# ## 텐서플로우 아키텍쳐
#
# <img src="https://developers.google.com/machine-learning/crash-course/images/TFHierarchy.svg">
#
# <sub>출처: https://developers.google.com/machine-learning/crash-course/first-steps-with-tensorflow/toolkit</sub>

# %% [markdown]
# ## 텐서플로우 시작하기

# %%
import numpy as np
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ### 텐서(Tensor)의 객체
# - 타입(Type): `string`, `float32`, `float16`, `int32`, `int8` 등
#
# - 형상(Shape): 0, 1, 2차원 등의 데이터 차원
#
# - 축(Rank): 차원의 개수

# %% [markdown]
# ### 텐서의 차원과 연산

# %%
a = tf.constant(2)
print(tf.rank(a))
print(a)
# Out:
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)

# %%
b = tf.constant([2, 3])
print(tf.rank(b))
print(b)
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor([2 3], shape=(2,), dtype=int32)

# %%
c = tf.constant([[2, 3], [6, 7]])
print(tf.rank(c))
print(c)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(
# [[2 3]
#  [6 7]], shape=(2, 2), dtype=int32)

# %%
d = tf.constant(['Hello'])
print(tf.rank(d))
print(d)
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor([b'Hello'], shape=(1,), dtype=string)

# %% [markdown]
# ### 난수 생성

# %%
rand = tf.random.uniform([1], 0, 1)
print(rand.shape)
print(rand)
# Out:
# (1,)
# tf.Tensor([0.6035812], shape=(1,), dtype=float32)

# %%
rand2 = tf.random.normal([1, 2], 0, 1)
print(rand2.shape)
print(rand2)
# Out:
# (1, 2)
# tf.Tensor([[-1.5988861 -0.7245168]], shape=(1, 2), dtype=float32)

# %%
rand3 = tf.random.normal(shape=(3, 2), mean=0, stddev=1)
print(rand3.shape)
print(rand3)
# Out:
# (3, 2)
# tf.Tensor(
# [[ 1.6996111  -2.0916398 ]
#  [-0.32680482  0.80408084]
#  [-0.65031093  0.85963625]], shape=(3, 2), dtype=float32)

# %% [markdown]
# ### 즉시 실행 모드 (Eager Mode) 지원
# - 즉시 실행모드를 통해 텐서플로우를 파이썬처럼 사용할 수 있음
#
# - 1.x 버전에서는 '그래프'를 생성하고, 초기화 한 뒤에 세션을 통해 **값을 흐르게 하는 작업**을 진행해야함

# %%
a = tf.constant(3)
b = tf.constant(2)

# %%
print(tf.add(a, b))
print(a + b)
# Out:
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)

# %%
print(tf.subtract(a, b))
print(a - b)
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)

# %%
print(tf.multiply(a, b))
print(a * b)
# Out:
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)

# %% [markdown]
# ### 텐서 플로우 ↔ 넘파이
# - `numpy()`
# - `tf.convet_to_tensor()`

# %%
c = tf.add(a, b).numpy()
print(type(c))
# Out:
# <class 'numpy.int32'>

# %%
c_square = np.square(c, dtype=np.float32)
c_tensor = tf.convert_to_tensor(c_square)

print(c_tensor)
print(type(c_tensor))
# Out:
# tf.Tensor(25.0, shape=(), dtype=float32)
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %% [markdown]
# ### 넘파이처럼 사용하기

# %%
t = tf.constant([[1., 2., 3.], [4., 5., 6.]])

print(t.shape)
print(t.dtype)
# Out:
# (2, 3)
# <dtype: 'float32'>

# %%
print(t[:, 1:])
# Out:
# tf.Tensor(
# [[2. 3.]
#  [5. 6.]], shape=(2, 2), dtype=float32)

# %%
t[..., 1, tf.newaxis]
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[2.],
#        [5.]], dtype=float32)>

# %%
t + 10
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[11., 12., 13.],
#        [14., 15., 16.]], dtype=float32)>

# %%
tf.square(t)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 1.,  4.,  9.],
#        [16., 25., 36.]], dtype=float32)>

# %%
t @ tf.transpose(t)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[14., 32.],
#        [32., 77.]], dtype=float32)>

# %% [markdown]
# ### 타입 변환
# - 텐서의 기본 dtype
#   - float형 텐서: `float32`
#   - int형 텐서: `int32`
#
# - 연산시 텐서의 타입을 맞춰줘야 함
#   - `float32` ~ `float32`
#   - `int32` ~ `int32`
#   - `flot32` ~ `int32` (x)
#
# - 타입변환에는 `tf.cast()` 사용

# %%
a = tf.constant(2)
print(a)

b = tf.constant(2.)
print(b)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(2.0, shape=(), dtype=float32)

# %%
#tf.constant(2.) + tf.constant(40)

# %%
#tf.constant(2.) + tf.constant(30., dtype=tf.float64)

# %%
t = tf.constant(30., dtype=tf.float64)
t2 = tf.constant(4.)

print(t2 + tf.cast(t, tf.float32))
# Out:
# tf.Tensor(34.0, shape=(), dtype=float32)

# %% [markdown]
# ### AutoGraph (오토그래프)
#
# - Tensorflow가 작업을 좀 더 빠르게 동작하게 하기 위한 방법으로 Graph로 만들어 연산을 진행
#
# - `tf.Graph`
#
# - 유연성이 있음
#
#   - 모바일 애플리케이션, 임베디드 기기, 백엔드 서버와 같이 Python 인터프리터가 없는 환경에서 Tensorflow 사용 가능

# %%
import timeit

# %% [markdown]
# ### @tf.function
# - 자동으로 그래프를 생성(Auto Graph)
#
# - 그래프로 변환하여 사용 -> GPU 연산 가능
#
# - 파이썬으로 구성된 함수를 텐서플로우의 그래프 형태로 다루고 싶을 때 사용가능
#
#
# - 원본 함수가 필요하다면 `(tf.function).python_function()`

# %%
@tf.function
def my_function(x):
  return x**2 - 10*x + 3

print(my_function(2))
print(my_function(tf.constant(2)))
# Out:
# tf.Tensor(-13, shape=(), dtype=int32)
# tf.Tensor(-13, shape=(), dtype=int32)

# %%
def my_function_(x):
  return x**2 - 10*x + 3

print(my_function_(2))
print(my_function_(tf.constant(2)))
# Out:
# -13
# tf.Tensor(-13, shape=(), dtype=int32)

# %%
tf_my_func = tf.function(my_function_)

print(tf_my_func)
print(tf_my_func(2))
# Out:
# <tensorflow.python.eager.def_function.Function object at 0x7fbed62b99e8>
# tf.Tensor(-13, shape=(), dtype=int32)

# %%
tf_my_func.python_function(2)
# Out:
# -13

# %%
def function_to_get_faster(x, y, b):
  x = tf.matmul(x, y)
  x = x + b
  return x

a_function_that_uses_a_graph = tf.function(function_to_get_faster)

x1 = tf.constant([[1.0, 2.0]])
y1 = tf.constant([[2.0], [3.0]])
b1 = tf.constant(4.0)

a_function_that_uses_a_graph(x1, y1, b1).numpy()
# Out:
# array([[12.]], dtype=float32)

# %%
def inner_function(x, y, b):
  x = tf.matmul(x, y)
  x = x + b
  return x

@tf.function
def outer_function(x):
  y = tf.constant([[2.0], [3.0]])
  b = tf.constant(4.0)
  return inner_function(x, y, b)

outer_function(tf.constant([[1.0, 2.0]])).numpy()
# Out:
# array([[12.]], dtype=float32)

# %% [markdown]
# 텐서플로우가 `tf.function`으로 변환한 코드

# %%
print(tf.autograph.to_code(my_function.python_function))
print(tf.autograph.to_code(tf_my_func.python_function))
print(tf.autograph.to_code(outer_function.python_function))
# Out:
# def tf__my_function(x):
#     with ag__.FunctionScope('my_function', 'fscope', ag__.ConversionOptions(recursive=True, user_requested=True, optional_features=(), internal_convert_user_code=True)) as fscope:
#         do_return = False
#         retval_ = ag__.UndefinedReturnValue()
#         try:
#             do_return = True
#             retval_ = (((ag__.ld(x) ** 2) - (10 * ag__.ld(x))) + 3)
#         except:
#             do_return = False
#             raise
#         return fscope.ret(retval_, do_return)
#
# def tf__my_function_(x):
#     with ag__.FunctionScope('my_function_', 'fscope', ag__.ConversionOptions(recursive=True, user_requested=True, optional_features=(), internal_convert_user_code=True)) as fscope:
#         do_return = False
#         retval_ = ag__.UndefinedReturnValue()
#         try:
#             do_return = True
#             retval_ = (((ag__.ld(x) ** 2) - (10 * ag__.ld(x))) + 3)
#         except:
#             do_return = False
#             raise
#         return fscope.ret(retval_, do_return)
#
# def tf__outer_function(x):
#     with ag__.FunctionScope('outer_function', 'fscope', ag__.ConversionOptions(recursive=True, user_requested=True, optional_features=(), internal_convert_user_code=True)) as fscope:
#         do_return = False
#         retval_ = ag__.UndefinedReturnValue()
#         y = ag__.converted_call(ag__.ld(tf).constant, ([[2.0], [3.0]],), None, fscope)
#         b = ag__.converted_call(ag__.ld(tf).constant, (4.0,), None, fscope)
#         try:
#             do_return = True
#             retval_ = ag__.converted_call(ag__.ld(inner_function), (ag__.ld(x), ag__.ld(y), ag__.ld(b)), None, fscope)
#         except:
#             do_return = False
#             raise
#         return fscope.ret(retval_, do_return)

# %% [markdown]
#  속도 향상

# %%
class SequentialModel(tf.keras.Model):
  def __init__(self, **kwargs):
    super(SequentialModel, self).__init__(**kwargs)
    self.flatten = tf.keras.layers.Flatten(input_shape=(28, 28))
    self.dense_1 = tf.keras.layers.Dense(128, activation='relu')
    self.dropout = tf.keras.layers.Dropout(0.2)
    self.dense_2 = tf.keras.layers.Dense(10)

  def call(self, x):
    x = self.flatten(x)
    x = self.dense_1(x)
    x = self.dropout(x)
    x = self.dense_2(x)
    return x

input_data = tf.random.uniform([60, 28, 28])

eager_model = SequentialModel()
graph_model = tf.function(eager_model)

print("Eager time:", timeit.timeit(lambda: eager_model(input_data), number=10000))
print("Graph time:", timeit.timeit(lambda: graph_model(input_data), number=10000))
# Out:
# Eager time: 7.803235932999996
# Graph time: 4.507837374999781

# %% [markdown]
# ### 변수 생성
#
# - `tf.Variable`
# - 딥러닝 모델 학습 시, 그래프 연산이 필요할 때 사용

# %%
X = tf.Variable(20.0)

print(X)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=20.0>

# %% [markdown]
# ### Autograd (자동 미분)
#
# - `tf.GradientTape` API를 사용
# - `tf.Variable` 같은 일부 입력에 대한 기울기 계산
#   - 기본적으로 한번만 사용됨
# - 변수가 포함된 연산만 기록

# %%
x = tf.Variable(3.0)

with tf.GradientTape() as tape:
  y = x**2

# %%
dy_dx = tape.gradient(y, x)
dy_dx.numpy()
# Out:
# 6.0

# %%
#x2 = tf.Variable(4)
#dy_dx = tape.gradient(y, x2)
#dy_dx.numpy()

# %%
x = tf.Variable(2.0)
y = tf.Variable(3.0)

with tf.GradientTape() as tape:
  y_sq = y**2
  z = x**2 + tf.stop_gradient(y_sq)

grad = tape.gradient(z, {'x':x, 'y':y})

print('dz/dx:', grad['x'])

print('dz/dy:', grad['y'])
# Out:
# dz/dx: tf.Tensor(4.0, shape=(), dtype=float32)
# dz/dy: None

# %%
weights = tf.Variable(tf.random.normal((3, 2)), name='weights')
biases = tf.Variable(tf.zeros(2, dtype=tf.float32), name='biases')
x = [[1., 2., 3.]]

with tf.GradientTape(persistent=True) as tape:
  y = x @ weights + biases
  loss = tf.reduce_mean(y**2)

# %%
[dl_dw, dl_db] = tape.gradient(loss, [weights, biases])

# %%
print(weights.shape)
print(dl_dw.shape)
# Out:
# (3, 2)
# (3, 2)

# %%
weights2 = tf.Variable(tf.random.normal((3, 2)), name='weights')
biases2 = tf.Variable(tf.zeros(2, dtype=tf.float32), name='biases')
x2 = [[4., 5., 6.]]

[dl_dw2, dl_db2] = tape.gradient(loss, [weights2, biases2])

print(weights2.shape)
print(dl_dw.shape)
# Out:
# (3, 2)
# (3, 2)

# %%
del tape

# %% [markdown]
# ## 간단한 신경망 구조

# %% [markdown]
# ### 뉴런
# - 입력 → 연산 → 활성화함수 → 출력

# %%
def sigmoid(x):
  return (1 / (1 + np.exp(-x)))

def Neuron(x, W, bias=0):
  z = x * W + bias
  return sigmoid(z)

# %%
x = tf.random.normal((1, 2), 0, 1)
W = tf.random.normal((1, 2), 0, 1)

print('x.shape:', x.shape)
print('W.shape:', W.shape)

print(x)
print(W)

print(Neuron(x, W))
# Out:
# x.shape: (1, 2)
# W.shape: (1, 2)
# tf.Tensor([[ 0.19997723 -0.19482802]], shape=(1, 2), dtype=float32)
# tf.Tensor([[-0.10212998  0.3782163 ]], shape=(1, 2), dtype=float32)
# [[0.49489424 0.48158658]]

# %%
x = tf.random.normal((2, 1), 0, 1)
W = tf.random.normal((2, 1), 0, 1)

print('x.shape:', x.shape)
print('W.shape:', W.shape)

print(x)
print(W)

print(Neuron(x, W))
# Out:
# x.shape: (2, 1)
# W.shape: (2, 1)
# tf.Tensor(
# [[0.30454758]
#  [3.1094089 ]], shape=(2, 1), dtype=float32)
# tf.Tensor(
# [[ 0.04972448]
#  [-1.5570754 ]], shape=(2, 1), dtype=float32)
# [[0.5037858]
#  [0.0078327]]

# %%
x = tf.random.normal((1,), 0, 1)
W = tf.random.normal((2, 1), 0, 1)

print('x.shape:', x.shape)
print('W.shape:', W.shape)

print(x)
print(W)

print(Neuron(x, W))
# Out:
# x.shape: (1,)
# W.shape: (2, 1)
# tf.Tensor([-0.04283835], shape=(1,), dtype=float32)
# tf.Tensor(
# [[0.714194 ]
#  [1.5642964]], shape=(2, 1), dtype=float32)
# [[0.49235183]
#  [0.48325327]]

# %% [markdown]
# ### 퍼셉트론 학습 알고리즘 (가중치 업데이트)
#
# ## $\qquad w^{(next step)} = w + \eta \ (y - \tilde{y}) \ x$
#
# - $w \ $: 가중치
#
# - $\eta \ $ : 학습률
#
# - $y \ $ : 정답 레이블
#
# - $\tilde{y} \ $: 예측 레이블

# %%
x = 1
y = 0
W = tf.random.normal([1], 0, 1)
print(Neuron(x, W))
print('y:', y)
# Out:
# [0.796672]
# y: 0

# %%
for i in range(1000):
  output = Neuron(x, W)
  error = y - output
  W = W + x * 0.1 * error

  if i % 100 == 99:
    print("{}\t{}\t{}".format(i+1, error, output))
# Out:
# 100	[-0.12587668]	[0.12587668]
# 200	[-0.05834487]	[0.05834487]
# 300	[-0.03745799]	[0.03745799]
# 400	[-0.0274786]	[0.0274786]
# 500	[-0.02166373]	[0.02166373]
# 600	[-0.01786573]	[0.01786573]
# 700	[-0.01519374]	[0.01519374]
# 800	[-0.01321315]	[0.01321315]
# 900	[-0.01168715]	[0.01168715]
# 1000	[-0.01047572]	[0.01047572]

# %%
def Neuron2(x, W, bias=0):
  z = tf.matmul(x, W, transpose_b=True) + bias
  return sigmoid(z)

# %%
x = tf.random.normal((1, 3), 0, 1)
y = tf.ones(1)
W = tf.random.normal((1, 3), 0, 1)

print(Neuron2(x, W))
print("y:", y)
# Out:
# [[0.7544474]]
# y: tf.Tensor([1.], shape=(1,), dtype=float32)

# %%
for i in range(1000):
  output = Neuron2(x, W)
  error = y - output
  W = W + x * 0.1 * error

  if i % 100 == 99:
    print("{}\t{}\t{}".format(i+1, error, output))
# Out:
# 100	[[0.01923978]]	[[0.9807602]]
# 200	[[0.00980115]]	[[0.99019885]]
# 300	[[0.00656629]]	[[0.9934337]]
# 400	[[0.00493473]]	[[0.9950653]]
# 500	[[0.00395197]]	[[0.99604803]]
# 600	[[0.00329524]]	[[0.99670476]]
# 700	[[0.0028255]]	[[0.9971745]]
# 800	[[0.00247282]]	[[0.9975272]]
# 900	[[0.00219852]]	[[0.9978015]]
# 1000	[[0.00197875]]	[[0.99802125]]

# %%
x = tf.random.normal((1, 3), 0, 1)
weights = tf.random.normal((1, 3), 0, 1)
bias = tf.zeros((1, 1))

y = tf.ones((1, ))

print("x\t: {}\nweights\t: {}\nbias\t: {}".format(x, weights, bias))
# Out:
# x	: [[-0.16854852 -0.43381596 -2.94756   ]]
# weights	: [[ 2.0629933  -0.6087175  -0.43449336]]
# bias	: [[0.]]

# %%
for i in range(1000):
  output = Neuron2(x, weights, bias=bias)
  error = y - output
  weights = weights + x * 0.1 * error
  bias = bias + 1 * 0.1 * error
  
  if i % 100 == 99:
    print("{}\t{}\t{}".format(i+1, error, output))
# Out:
# 100	[[0.0099448]]	[[0.9900552]]
# 200	[[0.00501877]]	[[0.9949812]]
# 300	[[0.00335461]]	[[0.9966454]]
# 400	[[0.00251895]]	[[0.99748105]]
# 500	[[0.00201643]]	[[0.9979836]]
# 600	[[0.00168103]]	[[0.998319]]
# 700	[[0.00144118]]	[[0.9985588]]
# 800	[[0.00126129]]	[[0.9987387]]
# 900	[[0.00112134]]	[[0.99887866]]
# 1000	[[0.00100929]]	[[0.9989907]]

# %%
print("x\t: {}\nweights\t: {}\nbias\t: {}".format(x, weights, bias))
# Out:
# x	: [[-0.16854852 -0.43381596 -2.94756   ]]
# weights	: [[ 1.9659704  -0.85843545 -2.1312027 ]]
# bias	: [[0.57563144]]

# %% [markdown]
# ### AND Gate

# %%
X = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y = np.array([[1], [0], [0], [0]])

W = tf.random.normal([2], 0, 1)
b = tf.random.normal([1], 0, 1)
b_x = 1

for i in range(2000):
  error_sum = 0

  for j in range(4):
    output = sigmoid(np.sum(X[j] * W) + b_x + b)
    error = Y[j][0] - output
    W = W + X[j] * 0.1 * error
    b = b + b_x * 0.1 * error
    error_sum += error

  if i % 200 == 0:
    print("Epoch {:4d}\tError Sum {}".format(i, error_sum))

print("\n가중치\t: {}".format(W))
print("편향\t: {}".format(b))
# Out:
# Epoch    0	Error Sum [-2.6316135]
# Epoch  200	Error Sum [-0.11516307]
# Epoch  400	Error Sum [-0.06738212]
# Epoch  600	Error Sum [-0.04752787]
# Epoch  800	Error Sum [-0.03660248]
# Epoch 1000	Error Sum [-0.02970478]
# Epoch 1200	Error Sum [-0.02496559]
# Epoch 1400	Error Sum [-0.02151282]
# Epoch 1600	Error Sum [-0.01888988]
# Epoch 1800	Error Sum [-0.01682896]
#
# 가중치	: [6.9599676 6.9631257]
# 편향	: [-11.619098]

# %%
for i in range(4):
  print("X: {} Y: {} Output: {}".format(X[i], Y[i], sigmoid(np.sum(X[i] * W) + b)))
# Out:
# X: [1 1] Y: [1] Output: [0.90920746]
# X: [1 0] Y: [0] Output: [0.00938577]
# X: [0 1] Y: [0] Output: [0.00941518]
# X: [0 0] Y: [0] Output: [8.992616e-06]

# %% [markdown]
# ### OR Gate

# %%
X2 = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y2 = np.array([[1], [1], [1], [0]])
W2 = tf.random.normal([2], 0, 1)
b2 = tf.random.normal([1], 0, 1)
b_x = 1

for i in range(2000):
  error_sum = 0

  for j in range(4):
    output = sigmoid(np.sum(X2[j] * W2) + b_x + b2)
    error = Y2[j][0] - output
    W2 = W2 + X2[j] * 0.1 * error
    b2 = b2 + b_x * 0.1 * error
    error_sum += error

  if i % 200 == 0:
    print("Epoch {:4d}\tError Sum {}".format(i, error_sum))

print("\n가중치\t: {}".format(W2))
print("편향\t: {}".format(b2))
# Out:
# Epoch    0	Error Sum [-0.7287403]
# Epoch  200	Error Sum [-0.04474396]
# Epoch  400	Error Sum [-0.02447658]
# Epoch  600	Error Sum [-0.01674282]
# Epoch  800	Error Sum [-0.01268178]
# Epoch 1000	Error Sum [-0.01018883]
# Epoch 1200	Error Sum [-0.00850692]
# Epoch 1400	Error Sum [-0.00729696]
# Epoch 1600	Error Sum [-0.00638483]
# Epoch 1800	Error Sum [-0.00567493]
#
# 가중치	: [8.23293  8.230172]
# 편향	: [-4.650309]

# %%
for i in range(4):
  print("X: {} Y: {} Output: {}".format(X2[i], Y2[i], sigmoid(np.sum(X2[i] * W2) + b2)))
# Out:
# X: [1 1] Y: [1] Output: [0.9999926]
# X: [1 0] Y: [1] Output: [0.9729494]
# X: [0 1] Y: [1] Output: [0.9728767]
# X: [0 0] Y: [0] Output: [0.00946814]

# %% [markdown]
# ### XOR Gate

# %%
X3 = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y3 = np.array([[0], [1], [1], [0]])
W3 = tf.random.normal([2], 0, 1)
b3 = tf.random.normal([1], 0, 1)
b_x = 1

for i in range(2000):
  error_sum = 0

  for j in range(4):
    output = sigmoid(np.sum(X3[j] * W3) + b_x + b3)
    error = Y3[j][0] - output
    W3 = W3 + X3[j] * 0.1 * error
    b3 = b3 + b_x * 0.1 * error
    error_sum += error

  if i % 200 == 0:
    print("Epoch {:4d}\tError Sum {}".format(i, error_sum))

print("\n가중치\t: {}".format(W3))
print("편향\t: {}".format(b3))
# Out:
# Epoch    0	Error Sum [1.0142517]
# Epoch  200	Error Sum [0.00364906]
# Epoch  400	Error Sum [0.00014842]
# Epoch  600	Error Sum [6.0796738e-06]
# Epoch  800	Error Sum [5.364418e-07]
# Epoch 1000	Error Sum [5.364418e-07]
# Epoch 1200	Error Sum [5.364418e-07]
# Epoch 1400	Error Sum [5.364418e-07]
# Epoch 1600	Error Sum [5.364418e-07]
# Epoch 1800	Error Sum [5.364418e-07]
#
# 가중치	: [5.1282927e-02 1.0840595e-06]
# 편향	: [-1.0000017]

# %%
for i in range(4):
  print("X: {} Y: {} Output: {}".format(X3[i], Y3[i], sigmoid(np.sum(X3[i] * W3) + b3)))
# Out:
# X: [1 1] Y: [0] Output: [0.2791428]
# X: [1 0] Y: [1] Output: [0.27914256]
# X: [0 1] Y: [1] Output: [0.2689413]
# X: [0 0] Y: [0] Output: [0.2689411]

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

np.random.seed(111)

X4 = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y4 = np.array([[0], [1], [1], [0]])

model = Sequential([Dense(units=2, activation='sigmoid', input_shape=(2, )),
                    Dense(units=1, activation='sigmoid')])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1), loss='mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X4, Y4, epochs=2000, batch_size=1, verbose=1)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2619
# Epoch 2/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2617
# Epoch 3/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2616
# Epoch 4/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2614
# Epoch 5/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2613
# Epoch 6/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2611
# Epoch 7/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2610
# Epoch 8/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2608
# Epoch 9/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2607
# Epoch 10/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2606
# Epoch 11/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2606
# Epoch 12/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2605
# Epoch 13/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2604
# Epoch 14/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2603
# Epoch 15/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2603
# Epoch 16/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2601
# Epoch 17/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2602
# Epoch 18/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2601
# Epoch 19/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2601
# Epoch 20/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2600
# Epoch 21/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2599
# Epoch 22/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2599
# Epoch 23/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2598
# Epoch 24/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2598
# Epoch 25/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2596
# Epoch 26/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2596
# Epoch 27/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2596
# Epoch 28/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2596
# Epoch 29/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2594
# Epoch 30/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2595
# Epoch 31/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2595
# Epoch 32/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2594
# Epoch 33/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2593
# Epoch 34/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2592
# Epoch 35/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2593
# Epoch 36/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2592
# Epoch 37/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2592
# Epoch 38/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2592
# Epoch 39/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2591
# Epoch 40/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2591
# Epoch 41/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2591
# Epoch 42/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2590
# Epoch 43/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2590
# Epoch 44/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2589
# Epoch 45/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2588
# Epoch 46/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2589
# Epoch 47/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2589
# Epoch 48/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2588
# Epoch 49/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2588
# Epoch 50/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2588
# Epoch 51/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2586
# Epoch 52/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2586
# Epoch 53/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2587
# Epoch 54/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2586
# Epoch 55/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2586
# Epoch 56/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2586
# Epoch 57/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2585
# Epoch 58/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2585
# Epoch 59/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2585
# Epoch 60/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2585
# Epoch 61/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2584
# Epoch 62/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2583
# Epoch 63/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2583
# Epoch 64/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2583
# Epoch 65/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2583
# Epoch 66/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2582
# Epoch 67/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2583
# Epoch 68/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2581
# Epoch 69/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2582
# Epoch 70/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2582
# Epoch 71/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2582
# Epoch 72/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2580
# Epoch 73/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2581
# Epoch 74/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2581
# Epoch 75/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2581
# Epoch 76/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2579
# Epoch 77/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2580
# Epoch 78/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2580
# Epoch 79/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2580
# Epoch 80/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2578
# Epoch 81/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2579
# Epoch 82/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2579
# Epoch 83/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2579
# Epoch 84/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2577
# Epoch 85/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2578
# Epoch 86/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2578
# Epoch 87/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2578
# Epoch 88/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2578
# Epoch 89/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2577
# Epoch 90/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2576
# Epoch 91/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2576
# Epoch 92/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2577
# Epoch 93/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2577
# Epoch 94/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2576
# Epoch 95/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2575
# Epoch 96/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2575
# Epoch 97/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2576
# Epoch 98/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.
2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2450
# Epoch 1916/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2449
# Epoch 1917/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2449
# Epoch 1918/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2449
# Epoch 1919/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2449
# Epoch 1920/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2448
# Epoch 1921/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2448
# Epoch 1922/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2447
# Epoch 1923/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2447
# Epoch 1924/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2446
# Epoch 1925/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2446
# Epoch 1926/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2446
# Epoch 1927/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2445
# Epoch 1928/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2445
# Epoch 1929/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2444
# Epoch 1930/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2444
# Epoch 1931/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2443
# Epoch 1932/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2443
# Epoch 1933/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2442
# Epoch 1934/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2442
# Epoch 1935/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2441
# Epoch 1936/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2441
# Epoch 1937/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2440
# Epoch 1938/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2440
# Epoch 1939/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2439
# Epoch 1940/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2439
# Epoch 1941/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2439
# Epoch 1942/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2437
# Epoch 1943/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2437
# Epoch 1944/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2436
# Epoch 1945/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2437
# Epoch 1946/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2436
# Epoch 1947/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2435
# Epoch 1948/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2435
# Epoch 1949/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2434
# Epoch 1950/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2434
# Epoch 1951/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2433
# Epoch 1952/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2432
# Epoch 1953/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2433
# Epoch 1954/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2432
# Epoch 1955/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2432
# Epoch 1956/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2431
# Epoch 1957/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2431
# Epoch 1958/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2430
# Epoch 1959/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2430
# Epoch 1960/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2429
# Epoch 1961/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2429
# Epoch 1962/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2428
# Epoch 1963/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2427
# Epoch 1964/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2427
# Epoch 1965/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2427
# Epoch 1966/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2425
# Epoch 1967/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2426
# Epoch 1968/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2425
# Epoch 1969/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2424
# Epoch 1970/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2423
# Epoch 1971/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2423
# Epoch 1972/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2423
# Epoch 1973/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2422
# Epoch 1974/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2422
# Epoch 1975/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2421
# Epoch 1976/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2421
# Epoch 1977/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2419
# Epoch 1978/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2419
# Epoch 1979/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2419
# Epoch 1980/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2418
# Epoch 1981/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2418
# Epoch 1982/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2417
# Epoch 1983/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2416
# Epoch 1984/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2416
# Epoch 1985/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2415
# Epoch 1986/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2415
# Epoch 1987/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2414
# Epoch 1988/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2413
# Epoch 1989/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2413
# Epoch 1990/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2413
# Epoch 1991/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2411
# Epoch 1992/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2411
# Epoch 1993/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2411
# Epoch 1994/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2410
# Epoch 1995/2000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2410
# Epoch 1996/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2409
# Epoch 1997/2000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2409
# Epoch 1998/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2408
# Epoch 1999/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2407
# Epoch 2000/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2407

# %%
model.predict(X4)
# Out:
# array([[0.46286356],
#        [0.43227136],
#        [0.59211874],
#        [0.49383098]], dtype=float32)

# %% [markdown]
# ## 시각화 사용

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

x = range(50)
y = tf.random.normal([50], 0, 1)
plt.plot(x, y)
plt.show()

# %%
x = range(50)
y = tf.random.normal([50], 0, 1)
plt.plot(x, y, 'ro')
plt.show()

# %%
x = range(30)
y = tf.random.normal([30], 0, 1)
plt.plot(x, y, 'g-')
plt.show()

# %%
x = range(30)
y = tf.random.normal([30], 0, 1)
plt.plot(x, y, 'b--')
plt.show()

# %%
random_normal = tf.random.normal([10000], 0, 1)
plt.hist(random_normal, bins=100)
plt.show()

# %% [markdown]
# ### XOR Gate의 'LOSS' 시각화

# %%
plt.plot(history.history['loss']);
